# %%
import pandas as pd
import geodatasets
import geopandas as gpd
from shapely.geometry import Point
import matplotlib.pyplot as plt
import folium

# %%
# Load the data from the file
df = pd.read_csv('Output.csv')

# Drop rows where 'lat_long_manual' is NA
df = df.dropna(subset=['lat_long_manual'])

# world = gpd.read_file(geodatasets.get_path('naturalearth_cultural'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 7
#       4 # Drop rows where 'lat_long_manual' is NA
#       5 df = df.dropna(subset=['lat_long_manual'])
# ----> 7 world = gpd.read_file(geodatasets.get_path('naturalearth_cultural'))
#
# File ~/Desktop/Columbia/DSI/myenv/lib/python3.9/site-packages/geodatasets/api.py:86, in get_path(name)
#      49 def get_path(name):
#      50     """Get the absolute path to a file in the local storage.
#      51
#      52     If it’s not in the local storage, it will be downloaded.
#    (...)
#      84     '/Users/martin/Library/Caches/geodatasets/airbnb.zip'
#      85     """
# ---> 86     dataset = data.query_name(name)
#      87     if "members" in dataset.keys():
#      88         unzipped_files = CACHE.fetch(
#      89             dataset.filename, processor=pooch.Unzip(members=dataset.members)
#      90         )
#
# File ~/Desktop/Columbia/DSI/myenv/lib/python3.9/site-packages/geodatasets/lib.py:120, in Bunch.query_name(self, name)
#     117 if name_clean in xyz_flat_lower:
#     118     return xyz_flat_lower[name_clean]
# --> 120 raise ValueError(f"No matching item found for the query '{name}'.")
#
# ValueError: No matching item found for the query 'naturalearth_cultural'.

# %%
# Split the 'lat_long_manual' column into 'latitude' and 'longitude'
df[['lat', 'long']] = df['lat_long_manual'].str.split(', ', expand=True)
df['lat'] = pd.to_numeric(df['lat'])
df['long'] = pd.to_numeric(df['long'])

# Create a base map centered around the average of the coordinates
m = folium.Map(location=[df['lat'].mean(), df['long'].mean()], zoom_start=2)

# Add points to the map
for _, row in df.iterrows():
    folium.Marker(location=[row['lat'], row['long']]).add_to(m)

# Save the map to an HTML file
m.save('map.html')

# If you want to display it directly in a Jupyter Notebook, use:
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c9728a5bf946b53644478b8c6e86aa3e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c9728a5bf946b53644478b8c6e86aa3e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c9728a5bf946b53644478b8c6e86aa3e = L.map(
#                 &quot;map_c9728a5bf946b53644478b8c6e86aa3e&quot;,
#                 {
#                     center: [-22.86101928356617, -43.351600101855105],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e15e49aef0ff3c27cfbadcd1a926c6f6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e15e49aef0ff3c27cfbadcd1a926c6f6.addTo(map_c9728a5bf946b53644478b8c6e86aa3e);
#
#
#             var marker_9832c5d446de00911777cea6212f7ade = L.marker(
#                 [-22.84077539526085, -43.37111139173495],
#                 {}
#             ).addTo(map_c9728a5bf946b53644478b8c6e86aa3e);
#
#
#             var marker_656810f087e4481a48be52e04336f805 = L.marker(
#                 [-22.84844645052041, -43.26440713806645],
#                 {}
#             ).addTo(map_c9728a5bf946b53644478b8c6e86aa3e);
#
#
#             var marker_a627f8acc360b6fd0a52432bda9b40b0 = L.marker(
#                 [-22.900671874145853, -43.17179020017052],
#                 {}
#             ).addTo(map_c9728a5bf946b53644478b8c6e86aa3e);
#
#
#             var marker_466c437bc9467af53d0c35b8bfdc2aa6 = L.marker(
#                 [-22.9148672320332, -43.20441532651803],
#                 {}
#             ).addTo(map_c9728a5bf946b53644478b8c6e86aa3e);
#
#
#             var marker_e2d27e3e2a2d70cb336b3bb48d8ee5af = L.marker(
#                 [-22.91061429417532, -43.195708546501486],
#                 {}
#             ).addTo(map_c9728a5bf946b53644478b8c6e86aa3e);
#
#
#             var marker_c1d11f18b572849b51c55abf749281a8 = L.marker(
#                 [-22.88403065806505, -43.421321001964685],
#                 {}
#             ).addTo(map_c9728a5bf946b53644478b8c6e86aa3e);
#
#
#             var marker_52ebfa95fac433ac7ce0b06750eb0355 = L.marker(
#                 [-22.902358175189377, -43.30607934346378],
#                 {}
#             ).addTo(map_c9728a5bf946b53644478b8c6e86aa3e);
#
#
#             var marker_4a1c607b9ee3fba2025e75beed939b86 = L.marker(
#                 [-22.904732016000057, -43.178890644305326],
#                 {}
#             ).addTo(map_c9728a5bf946b53644478b8c6e86aa3e);
#
#
#             var marker_72f34fe2f1af70d7abc6b00a00dfeec1 = L.marker(
#                 [-22.89200229191993, -43.48040289206117],
#                 {}
#             ).addTo(map_c9728a5bf946b53644478b8c6e86aa3e);
#
#
#             var marker_c39b12d8fa6de52770f1fe201906c348 = L.marker(
#                 [-21.968853958267022, -47.53414215375453],
#                 {}
#             ).addTo(map_c9728a5bf946b53644478b8c6e86aa3e);
#
#
#             var marker_527ab72adcfb622d8319095cc87caa5b = L.marker(
#                 [-22.92419620288266, -43.17924159702848],
#                 {}
#             ).addTo(map_c9728a5bf946b53644478b8c6e86aa3e);
#
#
#             var marker_fe38f5b4dbb175d5c995d2c3d4323688 = L.marker(
#                 [-22.938545896070803, -43.17659844569827],
#                 {}
#             ).addTo(map_c9728a5bf946b53644478b8c6e86aa3e);
#
#
#             var marker_f24e1aaa0e0632fe6edac03e0b9943a3 = L.marker(
#                 [-22.850496013307136, -43.242575177929545],
#                 {}
#             ).addTo(map_c9728a5bf946b53644478b8c6e86aa3e);
#
#
#             var marker_df522014352f36836eb69e951218fb7d = L.marker(
#                 [-22.7978990775448, -43.43938242781858],
#                 {}
#             ).addTo(map_c9728a5bf946b53644478b8c6e86aa3e);
#
#
#             var marker_80d671963091c3324540e12d6456027f = L.marker(
#                 [-22.919841548086524, -43.09422493764253],
#                 {}
#             ).addTo(map_c9728a5bf946b53644478b8c6e86aa3e);
#
#
#             var marker_65c26524e314c91b750be7485e3b36f2 = L.marker(
#                 [-22.89643119648912, -43.30341891292954],
#                 {}
#             ).addTo(map_c9728a5bf946b53644478b8c6e86aa3e);
#
#
#             var marker_2ae9d5ba70a79db59d6fc7a3b5b11889 = L.marker(
#                 [-22.852550066766742, -43.23196486518738],
#                 {}
#             ).addTo(map_c9728a5bf946b53644478b8c6e86aa3e);
#
#
#             var marker_e0e16aece83a201e21a4a6a4a25124e8 = L.marker(
#                 [-22.899680332749583, -43.2348692375582],
#                 {}
#             ).addTo(map_c9728a5bf946b53644478b8c6e86aa3e);
#
#
#             var marker_983b22d038f325d32a1747e264a723b3 = L.marker(
#                 [-22.83929739509632, -43.25457964654523],
#                 {}
#             ).addTo(map_c9728a5bf946b53644478b8c
